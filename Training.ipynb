# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
ROOT_DIR = '/content/gdrive/My Drive/Deteccion de latas YOLOV8 v2'

# %%
# !pip install ultralytics
# !pip install Cython

# %%
import os
from ultralytics import YOLO


# Load a model
model = YOLO("yolov8n.pt")

# Use the model
results = model.train(data=os.path.join(ROOT_DIR, "data.yaml"), epochs=3)
# Out:
# Ultralytics YOLOv8.0.225 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !scp -r /content/runs '/content/gdrive/My Drive/Colab Notebooks'
